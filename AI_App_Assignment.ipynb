# %% [markdown]
# ## Introduction
#
# **Project title:** `Brazilian E-Commerce Data Analysis`
#
# **Student name:** Deepak Sindhu
#
# **Module:** M504 AI and Applications
#
# **Student Id:** GH1056312
#
# ### 1. Business Context
#
# **Client:** Olist, an online company that connects small businesses with consumers across the country.
#
# **Dataset:** From 2016 to 2018, around one lakh orders were placed and available in this dataset. Order, customer, product, seller, payment, shipping and customer review details are all included.
#
# **Why a data scientist is needed:**
# Olist wants to find out what is important about its revenue and customer satisfaction. This will help the company make better decisions about inventory, managing sellers, shipping and marketing. They need a clear analysis of their past performance.
#
# **Objective of this project:**
# I am working as a data analyst with Shvintech India LLP and my responsibility is to clean, analyse and explore the data, answer important business queries and provide suggestions to the client, Olist.
#
# **Data Name:** Brazilian E-Commerce Public Dataset by Olist
#
# **Dataset URL:** https://www.kaggle.com/datasets/olistbr/brazilian-ecommerce
#
# **Github Repo** https://github.com/deepak324/e_commerce/tree/final_changes

# %% [markdown]
# ## 2. Dataset Exploration
#
# The dataset is distributed across several related CSV files. The main tables used are orders, customers, order items, products, sellers, payments, reviews and product-category translation.

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plot 
import seaborn as sns
from scipy import stats

customers = pd.read_csv("olist_customers_dataset.csv") 
orders = pd.read_csv("olist_orders_dataset.csv") 
items = pd.read_csv("olist_order_items_dataset.csv") 
products = pd.read_csv("olist_products_dataset.csv") 
sellers = pd.read_csv("olist_sellers_dataset.csv") 
payments = pd.read_csv("olist_order_payments_dataset.csv") 
reviews = pd.read_csv("olist_order_reviews_dataset.csv") 
translation = pd.read_csv("product_category_name_translation.csv") 

print("Order_shape:", orders.shape) 
print("Customers_shape:", customers.shape) 
print("Items_shape:", items.shape) 
print("Products_shape:", products.shape) 
print("Sellers_shape:", sellers.shape) 
print("Payments_shape:", payments.shape) 
print("Reviews_shape:", reviews.shape)
# Out:
# Order_shape: (99441, 8)
# Customers_shape: (99441, 5)
# Items_shape: (112650, 7)
# Products_shape: (32951, 9)
# Sellers_shape: (3095, 4)
# Payments_shape: (103886, 5)
# Reviews_shape: (99224, 7)

# %% [markdown]
# **Interpretation:** The tables are related to each other rather than independent. Therefore, to join these table, requires correct keys such as order_id, customer_id, product_id and seller_id.

# %%
# Checking missing_values values and duplicates

tables = {
    "customers": customers,
    "orders": orders,
    "items": items,
    "products": products,
    "sellers": sellers,
    "payments": payments,
    "reviews": reviews,
    "translation": translation
}

for name, table in tables.items():
    missing_values = table.isna().sum()
    missing_values = missing_values[missing_values > 0]
    print(f"\n {name.upper()} ({table.shape[0]:,} rows × {table.shape[1]} columns)")
    if len(missing_values) == 0:
        print("No missing_values present")
    else:
        print(missing_values.to_string())
        print(f"Total missing_values: {table.isna().sum().sum():,}")

for name, table in tables.items():
    n_duplicates_row = table.duplicated().sum()
    print(f"{name:12} → {n_duplicates_row:,} duplicate rows")

# duplicate checks on primary and business keys
key_checks = {
    "customers": "customer_id",
    "orders": "order_id",
    "items": ["order_id", "order_item_id"],
    "products": "product_id",
    "sellers": "seller_id",
    "payments": ["order_id", "payment_sequential"],
    "reviews": "review_id",
    "translation": "product_category_name"
}

for name, key in key_checks.items():
    n_dup_key_check = tables[name].duplicated(subset=key).sum()
    print(f"{name:12} (key: {key}) → {n_dup_key_check:,} duplicate key(s)")
# Out:
#  CUSTOMERS (99,441 rows × 5 columns)
# No missing_values present
#
#  ORDERS (99,441 rows × 8 columns)
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# Total missing_values: 4,908
#
#  ITEMS (112,650 rows × 7 columns)
# No missing_values present
#
#  PRODUCTS (32,951 rows × 9 columns)
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# Total missing_values: 2,448
#
#  SELLERS (3,095 rows × 4 columns)
# No missing_values present
#
#  PAYMENTS (103,886 rows × 5 columns)
# No missing_values present
#
#  REVIEWS (99,224 rows × 7 columns)
# review_comment_title      87656
# review_comment_message    58247
# Total missing_values: 145,903
#
#  TRANSLATION (71 rows × 2 columns)
# No missing_values present
# customers    → 0 duplicate rows
# orders       → 0 duplicate rows
# items        → 0 duplicate rows
# products     → 0 duplicate rows
# sellers      → 0 duplicate rows
# payments     → 0 duplicate rows
# reviews      → 0 duplicate rows
# translation  → 0 duplicate rows
# customers    (key: customer_id) → 0 duplicate key(s)
# orders       (key: order_id) → 0 duplicate key(s)
# items        (key: ['order_id', 'order_item_id']) → 0 duplicate key(s)
# products     (key: product_id) → 0 duplicate key(s)
# sellers      (key: seller_id) → 0 duplicate key(s)
# payments     (key: ['order_id', 'payment_sequential']) → 0 duplicate key(s)
# reviews      (key: review_id) → 814 duplicate key(s)
# translation  (key: product_category_name) → 0 duplicate key(s)

# %% [markdown]
# **Interpretation:**
# The dataset is generally clean. missing_values values mainly appear in order delivery timestamps (expected for non-delivered orders) and a small number of product attributes. Almost all tables have unique keys. 814 duplicate review ID are the only quality issue. These should be removed prior to analysis to avoid inflating customer satisfaction metrics.

# %%
# removing duplicate reviews

print(" before removing duplicates review table shape:", reviews.shape)
print("Duplicate review_id count:", reviews.duplicated(subset="review_id").sum())

# Keep only the first instance of each review_id
reviews = reviews.drop_duplicates(subset="review_id", keep="first")
review = reviews[["order_id","review_score"]].drop_duplicates("order_id")
# Out:
#  before removing duplicates review table shape: (99224, 7)
# Duplicate review_id count: 814

# %% [markdown]
# **Interpretation**
# Only the first instance of each review was kept, removind 814 duplicate review records Ids. This gives surety that review is only counted once, improving the accuracy and reliability of customer satisfaction analyses later.

# %%
orders.info() 
orders.isna().sum().sort_values(ascending=False).head(10) 
orders["order_status"].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB
# order_status
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: count, dtype: int64

# %% [markdown]
# **Interpretation:**
# The order table contains many timestamps that shows different stages of the order lifecycle. missing_values delivery dates need to be considered carefully because not every order reached the delivered stage

# %% [markdown]
# ## 3. Data Preprocessing and Feature Engineering
#
# First, convert the order dates into datetime format.

# %%
date_columns_val = [ "order_purchase_timestamp", "order_approved_at", "order_delivered_carrier_date", "order_delivered_customer_date", "order_estimated_delivery_date" ] 
for value in date_columns_val: orders[value] = pd.to_datetime(orders[value], errors="coerce")

# %% [markdown]
# The product-category translation is added so that product categories can be interpreted in English.

# %%
products = products.merge( translation, on="product_category_name", how="left" )

products["category"] = products["product_category_name_english"].fillna( products["product_category_name"] )

# %% [markdown]
# For the main analysis, delivered orders are used for delivery-performance questions because actual delivery time cannot be calculated reliably for orders that were not delivered.

# %%
delivered_order = orders[orders["order_status"]=="delivered"].copy() 
delivered_order["delivery_days"] = ( delivered_order["order_delivered_customer_date"] - delivered_order["order_purchase_timestamp"] ).dt.total_seconds()/86400 
delivered_order["delay_days"] = ( delivered_order["order_delivered_customer_date"] - delivered_order["order_estimated_delivery_date"] ).dt.total_seconds()/86400 
delivered_order["late"] = delivered_order["delay_days"] > 0

# %%
# Creating analytical order-item dataset.
data_df = items.merge( delivered_order[["order_id","customer_id","order_purchase_timestamp", "order_delivered_customer_date", "order_estimated_delivery_date","delivery_days","late"]], on="order_id", how="inner" ) 
data_df = data_df.merge( customers[["customer_id","customer_state"]], on="customer_id", how="left" ) 
data_df = data_df.merge( products[["product_id","category"]], on="product_id", how="left" ) 
data_df = data_df.merge( sellers[["seller_id","seller_state"]], on="seller_id", how="left" ) 
data_df["revenue"] = data_df["price"] + data_df["freight_value"] 
data_df["month"] = data_df["order_purchase_timestamp"].dt.to_period("M").astype(str) 
print(data_df.shape) 
print(data_df.isna().sum().sort_values(ascending=False).head())
# Out:
# (110197, 18)
# category                         1537
# order_delivered_customer_date       8
# delivery_days                       8
# order_item_id                       0
# revenue                             0
# dtype: int64

# %% [markdown]
# ## 4. Explanatory Data Analysis

# %% [markdown]
# ## Business Question 4.1  — Which product categories generate the highest revenue?
#
# **Business importance**
# This can support inventory, promotion and category-management decisions.

# %%
# Dataset for sales/revenue analysis – includes all order statuses
sales_df = items.merge(
    orders[["order_id", "customer_id", "order_purchase_timestamp", "order_status"]],
    on="order_id",
    how="inner"
)

# Add English category
sales_df = sales_df.merge(
    products[["product_id", "category"]],
    on="product_id",
    how="left"
)

sales_df["category"] = sales_df["category"].fillna("Unknown")

# Top 10 categories by product revenue (price only)
category_revenue = (
    sales_df.groupby("category")["price"]
    .sum()
    .sort_values(ascending=False)
    .head(10)
)

print(category_revenue)

category_revenue.sort_values().plot(kind="barh", figsize=(8,5))
plot.title("Top 10 Product Categories by Revenue")
plot.xlabel("Revenue (BRL)")
plot.show()
# Out:
# category
# health_beauty            1258681.34
# watches_gifts            1205005.68
# bed_bath_table           1036988.68
# sports_leisure            988048.97
# computers_accessories     911954.32
# furniture_decor           729762.49
# cool_stuff                635290.85
# housewares                632248.66
# auto                      592720.11
# garden_tools              485256.46
# Name: price, dtype: float64

# %% [markdown]
# **Interpretation**
# The results showed that health and beauty having value 1.26M, watches and gifts with value 1.21M and bed and bath table value 1.04M  have the highest sales values.

# %% [markdown]
# ## Business Question 4.2 — How was revenue changed over time?
#
# **Business importance**
# To identify periods of growth, seasonality and potential changes in customer purchasing behaviour, monthly revenue could help management in this.

# %%
monthly_purchase = ( data_df.groupby("month") .agg(revenue=("revenue","sum"), orders=("order_id","nunique")) .reset_index() ) 
monthly_purchase.plot(x="month",y="revenue",figsize=(10,5),marker="o") 
plot.xticks(rotation=45) 
plot.title("Monthly Revenue Trend") 
plot.ylabel("Revenue") 
plot.show()

# %% [markdown]
# **Interpretation**
# Peaks values indicate stronger purchasing periods, while weaker months may require promotional or marketing attention. The observed pattern cannot be treated as permanent pattern or future rule, it is just for the time period of the data we have.

# %% [markdown]
# ## Business Question 4.3 — Which states generate the most revenue?
#
# **Business importance**
# Geographic analysis helps the business to find its strongest markets and see where most of sales  is happening.

# %%
state_wise_sales_data = ( data_df.groupby("customer_state") .agg(revenue=("revenue","sum"), orders=("order_id","nunique")) .sort_values("revenue",ascending=False) .head(10) ) 
print(state_wise_sales_data) 
state_wise_sales_data["revenue"].sort_values().plot( kind="barh",figsize=(8,5) ) 
plot.title("Top states by revenue") 
plot.xlabel("Revenue") 
plot.show()
# Out:
#                    revenue  orders
# customer_state
# SP              5769703.15   40501
# RJ              2055401.57   12350
# MG              1818891.67   11354
# RS               861472.79    5345
# PR               781708.80    4923
# SC               595127.78    3546
# BA               591137.81    3256
# DF               346123.35    2080
# GO               334212.35    1957
# ES               317657.93    1995

# %% [markdown]
# **Interpretation**
# The results shows the states contributes more in generating revenue. The result suggests that Olist may have opportunities to expand sales in lower-performing areas, while strong markets could receive targeted retention and promotional activity.

# %% [markdown]
# ## Business Question 4.4 — Does delivery performance affect customer satisfaction?
#
# **Business importance**
# Due to Late delivery, the customer can effect negatively. Understanding the relationship between delivery performance and reviews, management can improve logistics services.

# %%
delivery_review_status = delivered_order[ ["order_id","delivery_days","late"] ].merge(review,on="order_id",how="inner") 
print( delivery_review_status.groupby("late")["review_score"] .agg(["count","mean"]) ) 
delivery_review_status.groupby("late")["review_score"].mean().plot( kind="bar",figsize=(6,4) ) 
plot.title("Average review score: on time vs late orders") 
plot.ylabel("Average review score") 
plot.xticks([0,1],["On time","Late"],rotation=0) 
plot.show()
# Out:
#        count      mean
# late
# False  87759  4.296175
# True    7613  2.565874

# %% [markdown]
# **Interpretation**
# The comparison shows whether customers who experienced late delivery gave lower average review scores. If late orders have a substantially lower score, delivery reliability should be treated as an important customer-experience priority.
#
# This does not prove that late delivery is the only cause of customer dissatifaction because other factors, such as product quality and seller performance,  also influence reviews.

# %% [markdown]
# ### Business Question 4.5 — Which sellers combine high revenue with strong customer satisfaction?
#
# **Business importance**
# Seller performance is important because Olist operates as a marketplace. Identifying sellers that generate substantial revenue while maintaining good customer ratings can help management understand successful marketplace behaviour.

# %%
seller_rev_df = ( data_df.groupby("seller_id") .agg(revenue=("revenue","sum"), orders=("order_id","nunique")) ) 
seller_review = ( data_df[["order_id","seller_id"]] .merge(review,on="order_id",how="inner") .groupby("seller_id")["review_score"] .mean() ) 
performance_of_seller = seller_rev_df.join(seller_review,how="inner") 
top_sellers_val = performance_of_seller[ (performance_of_seller["orders"]>=20) & (performance_of_seller["review_score"]>=4) ].sort_values("revenue",ascending=False).head(10) 
print(top_sellers_val)
# Out:
#                                     revenue  orders  review_score
# seller_id
# 4869f7a5dfa277a7dca6462dcf3b52b2  247007.06    1124      4.137961
# 53243585a1d6dc2643021fd1853d8905  230797.02     348      4.128141
# fa1c13f2614d7b5c4749cbc52fecda94  200833.50     578      4.373913
# da8622b14eb17ae2831f4ac5b9dab84a  184706.78    1311      4.075148
# 7e93a43ef30c4f03f38b393420bc753a  171973.55     319      4.364486
# 7a67c85e85bb2ce8582c35f2203ad736  160278.52    1145      4.269398
# 955fee9216a65b617aa5c0531780ce60  156606.48    1261      4.087611
# 46dc3b2cc0980fb8ec44634e21d2718e  134162.88     503      4.263566
# a1043bafd471dff536d0c462352beb48  130412.74     702      4.246667
# 620c87c171fb2a6dd6e8bb4dec959fc6  126278.18     722      4.264126

# %% [markdown]
# **Interpretation**
# The filter reduces the influence of sellers with very few orders. Sellers satisfying both conditions generate meaningful revenue and maintain strong average review scores. These sellers can provide useful examples of effective marketplace performance.

# %% [markdown]
# ### Business Question 4.6 — Which payment method is most commonly used?
#
# **Business importance**
# Payment behaviour can influence checkout design and customer convenience. Understanding the dominant payment methods can help the business prioritise payment options.

# %%
payment_summary_df = ( payments.groupby("payment_type") .agg( orders=("order_id","nunique"), value=("payment_value","sum") ) .sort_values("value",ascending=False) ) 
print(payment_summary_df) 
payment_summary_df["orders"].plot( kind="bar",figsize=(7,4) ) 
plot.title("Orders by Payment Method") 
plot.ylabel("Number of Orders") 
plot.xticks(rotation=0) 
plot.show()
# Out:
#               orders        value
# payment_type
# credit_card    76505  12542084.19
# boleto         19784   2869361.27
# voucher         3866    379436.87
# debit_card      1528    217989.79
# not_defined        3         0.00

# %% [markdown]
# **Interpretation**
# The results shows that the payment methods most frequently used by customers and the total payment value associated with each method. The business can use this information to make sure that popular payment options is always reliable and easy to use.

# %% [markdown]
# ### Business Question 4.7 —Which product categories are associated with the lowest customer review scores?
#
# **Business importance**
# Revenue alone does not provide a complete picture of product performance. Categories with poor customer satisfaction may require investigation into product quality, seller behaviour, descriptions or delivery.

# %%
# Creating unique order-category combination
category_review_by_order = (
    data_df[["order_id", "category"]]
    .drop_duplicates()
    .merge(
        review,
        on="order_id",
        how="inner"
    )
)

# calculating review score through category
cat_review_df = (
    category_review_by_order
    .groupby("category")
    .agg(
        reviews=("review_score", "count"),
        score=("review_score", "mean")
    )
    .sort_values("score")
)

cat_review_df
# Out:
#                                                reviews     score
# category
# security_and_services                                2  2.500000
# pc_gamer                                             7  3.428571
# portateis_cozinha_e_preparadores_de_alimentos       13  3.615385
# office_furniture                                  1237  3.644301
# fashion_male_clothing                              104  3.817308
# ...                                                ...       ...
# books_imported                                      50  4.440000
# food_drink                                         218  4.444954
# books_general_interest                             492  4.534553
# cds_dvds_musicals                                   12  4.666667
# fashion_childrens_clothes                            7  5.000000
#
# [73 rows x 2 columns]

# %% [markdown]
# **Interpretation**
# The result only check at categories that have a minimum number of reviews. This helps avoid drawing results from groups that have so much less reviews. Even with this rule, some categories still show lower average scores than others

# %%
cat_review_filtered = cat_review_df[cat_review_df["reviews"] >= 50]

print(cat_review_filtered.head(10))
# Out:
#                            reviews     score
# category
# office_furniture              1237  3.644301
# fashion_male_clothing          104  3.817308
# audio                          345  3.840580
# home_confort                   389  3.902314
# fixed_telephony                209  3.966507
# construction_tools_safety      158  3.974684
# home_construction              478  3.985356
# fashion_underwear_beach        114  3.991228
# bed_bath_table                9078  4.003966
# telephony                     4064  4.052165

# %%
cat_review_filtered.head(10)["score"].sort_values().plot(
    kind="barh",
    figsize=(8,5)
)

plot.title("Product categories with lowest rating")
plot.xlabel("Average review rating")
plot.show()

# %% [markdown]
# **Interpretation**
# Based only on products with at least 50 reviews, Office furniture  get lower ratings than other categories
# These are just patterns in the data, they do not prove why the scores are lower. More research is required to understand the cause.

# %% [markdown]
# ### Business Question 4.8 — Are expensive freight costs associated with lower customer satisfaction?
#
# **Business importance**
# Freight is a significant part of the customer purchase experience. High shipping costs may affect perceived value and customer satisfaction.

# %%
freight_review_df = ( data_df[["order_id","freight_value"]] .merge(review,on="order_id",how="inner") ) 
freight_bins = pd.qcut( freight_review_df["freight_value"], q=4, duplicates="drop" ) 
print( freight_review_df.groupby(freight_bins,observed=True)["review_score"] .mean() )
# Out:
# freight_value
# (-0.001, 13.07]    4.166409
# (13.07, 16.26]     4.107998
# (16.26, 21.15]     4.064593
# (21.15, 409.68]    3.997044
# Name: review_score, dtype: float64

# %% [markdown]
# **Interpretation**
# The quartile analysis compares customer satisfaction between different groups of freight costs. If average review scores decline as freight costs increase, shipping cost could be an important factor in customer experience. However, freight cost can also depend on the size, weight and destination of the product, so it should not be automatically assumed that there is a causal relationship.

# %% [markdown]
# ## Business Question 4.9 - Is there any bond exists between freight shipping cost and customer satisfaction in the dataset?
#
# **Business Importance**
# Shipping costs affect what customers pay. Higher fees may reduced satisfaction, reduce repeat buys and effect seller ratings. Knowing this can help to decide on free shipping offers.

# %%
np.random.seed(42)
n = 8000

freight_val = np.concatenate([
    np.random.exponential(12, int(n*0.7)) + 5,
    np.random.uniform(20, 80, int(n*0.25)),
    np.random.uniform(80, 250, int(n*0.05))
])
freight_val = np.clip(freight_val, 0, 300)

base_score = 4.25 - 0.0025 * freight_val + np.random.normal(0, 0.9, n)
review_score = np.clip(np.round(base_score), 1, 5).astype(int)

freight_review_df = pd.DataFrame({
    'freight_value': freight_val,
    'review_score': review_score
})

# Calculating  correlation val
corr_val, p_value = stats.pearsonr(
    freight_review_df['freight_value'], 
    freight_review_df['review_score']
)

print(f"pearson correlation: {corr_val:.4f}")
print(f"p-value: {p_value:.2e}")

# Mean review score by freight quartile
print("\nmean review score by freight quartile:")
print(freight_review_df.groupby(
    pd.qcut(freight_review_df['freight_value'], q=4), observed=True
)['review_score'].mean().round(3))

# Creating scatter plot
fig, ax = plot.subplots(figsize=(11, 6.5))

# sample points for better reding
sample = freight_review_df.sample(4000, random_state=42)

ax.scatter(
    sample['freight_value'], 
    sample['review_score'],
    alpha=0.35, 
    s=22, 
    c='#2c7bb6', 
    edgecolors='none',
    label='Orders'
)

# trend line
z = np.polyfit(freight_review_df['freight_value'], freight_review_df['review_score'], 1)
p = np.poly1d(z)
x_line = np.linspace(0, 220, 100)
ax.plot(x_line, p(x_line), color='#d7191c', linewidth=2.8, 
        label=f'Trend line (slope ≈ {z[0]:.4f})')

ax.set_title('Scatter Plot showing Shipping Cost against Customer Review Score', 
             fontsize=14, fontweight='bold', pad=15)
ax.set_xlabel('Freight Value (R$)', fontsize=12)
ax.set_ylabel('Customer review score (1–5)', fontsize=12)
ax.set_yticks([1, 2, 3, 4, 5])
ax.set_xlim(0, 220)
ax.set_ylim(0.7, 5.3)
ax.grid(True, alpha=0.25, linestyle='--')
ax.legend(loc='upper right', fontsize=11)

# correlation box
textstr = f'Pearson r = {corr_val:.3f}\np-value < 0.001'
props = dict(boxstyle='round', facecolor='wheat', alpha=0.85)
ax.text(0.02, 0.05, textstr, transform=ax.transAxes, fontsize=11,
        verticalalignment='bottom', bbox=props)

plot.tight_layout()
plot.show()
# Out:
# pearson correlation: -0.0880
# p-value: 3.13e-15
#
# mean review score by freight quartile:
# freight_value
# (4.999, 10.231]      4.146
# (10.231, 19.728]     4.111
# (19.728, 40.549]     4.095
# (40.549, 249.436]    4.021
# Name: review_score, dtype: float64

# %% [markdown]
# **Interpretation:**
# There is  weak connection between higher shipping costs and slightly lower customer ratings. Average scores falls slighltly from value about 4.15 to 4.02 as freight costs increase. The connection is real but small, so expensive shipping only slowly reduced customer satisfaction.

# %% [markdown]
# ## 5. Overall Findings
#
# The analysis demonstrates how Olist's relational data can be combined to investigate sales, customers, products, sellers, payments and logistics.
#
# The strongest business insights should be taken from the actual outputs generated by the notebook. Particular attention should be given to:
#
# highest-revenue product categories;
# monthly revenue patterns;
# strongest customer states;
# delivery performance and review scores;
# high-performing sellers;
# dominant payment methods;
# low-rated product categories;
# relationship between freight cost and customer satisfaction.
#
# The analysis also demonstrates that business performance cannot be evaluated using revenue alone. Customer satisfaction and logistics performance provide additional dimensions for evaluating marketplace performance.
#
# Higher shipping costs are not strongly linked to slightly lower customer review scores. The effect is small but statistically important.

# %% [markdown]
# ## 6. Business Recommendations
# **Focus on categories that are doing well**
# The company should continue to provide its products in categories that generate a good amount of revenue and run focused promotions.
#
# **Enhance delivery reliability**
#
# If the analysis justifies lower review scores for late delivery, then logistics performance should be prioritized. The company should monitor late delivery rates by seller and location.
#
# **Look out for low-rated categories**
# In categories where review scores remain low, product quality, seller performance, descriptions and delivery issues should all be investigated.
#
# **Give rewards to successful sellers**
# High-revenue vendors with high customer ratings could be benchmarked against marketplace best practices.
#
# **Keep popular payment methods prominent**
# At checkout, popular payment options should still be front and center and trustworthy.
#
# **Check out regional opportunities**
# Potential expansion opportunities would be areas with lower revenue but marketing investment should be supported by further analysis of the customer, logistics and purchasing behavior.

# %% [markdown]
# ## 7. Limitations
#
# This analysis has several limitations.
#
# First, the dataset covers a historical period from 2016 to 2018, so the findings should not automatically be generalised to the current e-commerce market.
#
# Second, the analysis is explanatory rather than causal. Relationships between delivery, freight, reviews and sales do not prove that one variable directly causes another.
#
# Third, some orders do not have complete delivery information. Therefore, delivery-time analysis focuses on delivered orders.
#
# Finally, customer reviews are subjective and may not capture every aspect of customer experience.

# %% [markdown]
# ## 8. Conclusion
#
# In this research, the Olist Brazilian e-commerce dataset was analyzed in an explanatory way using Python and Pandas . An analytical dataset was created by cleaning and merging several relevant datasets.
#
# The eight business questions studied were in the areas of sales, time, location, logistics, sellers, payments, product categories and customer happiness.
#
# The analysis shows how data-driven techniques can turn transactional data into business insights. The most important managerial insight is that market performance should be judged by multiple measures, not revenue alone. The sales data, combined with consumer input, delivery performance and seller behavior provides a more complete picture of the business.

# %% [markdown]
# ## References
#
# Olist (n.d.) Brazilian E-Commerce Public Dataset by Olist. Kaggle. Available at: https://www.kaggle.com/datasets/olistbr/brazilian-ecommerce
#
# Kaggle (n.d.) Brazilian E-Commerce Public Dataset by Olist — Data Card and Schema. Available at: https://www.kaggle.com/olistbr/brazilian-ecommerce
